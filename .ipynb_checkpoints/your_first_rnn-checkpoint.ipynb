# %% [markdown]
# # İlk Tekrarlayan Sinir Ağınız (RNN)

# %% [markdown]
# 🙌 RNN'lere hoş geldiniz! Önceki derste görseller (uzamsal veri) ile ilgilenmek için CNN'leri kullandıktan sonra, şimdi zamanla ilgili veriler (***zamansal veri***) ile ilgileneceksiniz.
#
# 🎯 Bu ısınma challenge'ının hedefleri:
#
# 1. Zamansal verinin ne olduğunu anlamak
# 2. İlk Tekrarlayan Sinir Ağlarınızı oluşturmak

# %% [markdown]
# _Not: Google Colab kullanmaya gerek yok ❌_

# %% [markdown]
# ## (1) 📚 Veri seti

# %% [markdown]
# _Uyarı: bu bölümde kendiniz kod yazmanıza gerek yok, dikkatli okuyun ve hücreleri çalıştırın. RNN ve LSTM modellerine odaklanmanızı istiyoruz, Python sorularına değil_ 😉

# %% [markdown]
# 🔢 Bir şirketteki çalışanlar hakkında bazı verilere erişimimiz olduğunu düşünün.

# %%
import numpy as np

X = np.load('X.npy')
y = np.load('y.npy')

# %%
X.shape, y.shape
# Out:
# ((25000, 10, 3), (25000,))

# %% [markdown]
# ☝️ Veri seti **25.000 çalışanın istihdam durumunun yıllar içindeki gelişimini** tanımlar: her sekans 10 ardışık yıla karşılık gelir ve her yıl 3 bileşenden oluşan bir iş durumunu açıklar
# - maaş,
# - sorumluluğundaki kişi sayısı,
# - şirketin büyüklüğü.
#
# 🕵🏻 Veri setini biraz daha iyi anlamak için ilk çalışanın verilerine bakalım.

# %%
import pandas as pd

employee_0 = pd.DataFrame(X[0],
                          columns=['salary',
                                   'responsibility',
                                   'company_size'])
round(employee_0,2)
# Out:
#    salary  responsibility  company_size
# 0    0.80           10.73         102.0
# 1    0.50           10.73         102.0
# 2    0.60           10.73         102.0
# 3    0.71           10.73         130.0
# 4    0.94           10.73         130.0
# 5    1.05           10.73         130.0
# 6    1.12           32.00         108.0
# 7    4.87           32.00         108.0
# 8    4.97           33.00         108.0
# 9    5.20           39.00         108.0

# %% [markdown]
# 🎯 Bu challenge'ın amacı, geçmiş gözlemlere dayanarak bu 25.000 çalışanın her biri için 11. yıldaki aylık maaşı tahmin etmektir.

# %%
# For example, the first employee earns 6.499 k USD per month
# during the 11th year at the company
y[0]
# Out:
# 6.499

# %% [markdown]
# 📈 Maaşların, sorumluluklarındaki kişi sayısının ve şirket büyüklüğünün yıllar içindeki gelişimini daha iyi anlamanız için aşağıdaki hücreyi çalıştırabilirsiniz. Bu üç değişken arasında görsel olarak bazı korelasyonlar tespit edebiliyor musunuz?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

number_of_employees = len(X)

### Choosing random employees
##### As the employees are selected randomly, feel free to re-run this cell a few times !

number_of_randomly_selected_employees = 5

random_selection = np.random.randint(0,
                                     number_of_employees,
                                     number_of_randomly_selected_employees)


### Plotting data for the selected employees

plt.title('Salary')
for r in random_selection:
    plt.plot(X[r, :, 0],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('# People responsibile for')
for r in random_selection:
    plt.plot(X[r, :, 1],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('Company sizes')
for r in random_selection:
    plt.plot(X[r, :, 2],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# 🕵🏻 **Veri Keşfi** 🕵🏻 Gözlemlerin değişkenliğini daha iyi anlamak için şunların dağılımına bakın:
# * 10. yıldaki tüm maaşlar,
# * sorumluluğundaki kişiler,
# * ve şirket büyüklükleri

# %%
import seaborn as sns

plt.title("Salaries on the 10th year")
sns.histplot(X[:, -1, 0].flatten()) # all the employees, last year, feature #0 = salaries
plt.show()

plt.title("# of people under someone's responsibility")
sns.histplot(X[:, :, 1].flatten()) # all the employees, all the years, feature #1 = responsabilities
plt.show()

plt.title("Company size")
sns.histplot(X[:, :, 2].flatten()) # all the employees, all the years, feature #2 = company size
plt.show()

# %% [markdown]
# ✂️ **Tutma yöntemi** Veri setini eğitim ve test setine ayıralım (80/20)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# Notice that we are train_test_splitting the 25 000 employees!

# %% [markdown]
# ## (2) 💻 Basit bir RNN

# %% [markdown]
# 🤗 Artık bu şirketin veri setiyle tanıştığınıza göre, ilk Tekrarlayan Sinir Ağınızı oluşturacaksınız. Basit bir mimariyle başlayalım.

# %% [markdown]
# ❓ **Soru** ❓ Şunları içeren bir model yazın:
# - Eğitim setine uyarlanmış bir ***Normalization*** katmanı
# - 20 *ünite* içeren bir ***SimpleRNN*** katmanı (Tekrarlayan Katman için aktivasyon fonksiyonu olarak `tanh`'ın daha uygun olduğunu unutmayın)
# - 10 nöronlu bir ***Dense*** katmanı
# - Görevinize özel bir ***Dense*** katmanı (= maaş ***tahmini*** yapmak için)
#
# 👩🏻‍🏫 Unutmayın: İlk katmandan önce `keras.Input` eklemeyi unutmayın.

# %%
from keras import Sequential, Input
from keras.layers import Dense, SimpleRNN, Flatten, Normalization
# Out:
# 2026-03-27 14:43:44.947141: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# 1. Normalizasyon katmanını oluştur ve eğitim verisine uyarlıyoruz
# Bu işlem, verideki ortalama ve varyansı hesaplayarak veriyi ölçeklendirir.
normalizer = Normalization()
normalizer.adapt(X_train)

# 2. Modeli oluştur
model = Sequential()

# İlk katmandan önce Input ekliyoruz (10 zaman adımı, 3 özellik)
model.add(Input(shape=(10, 3)))

# Eğitim setine uyarlanmış Normalization katmanı
model.add(normalizer)

# 20 üniteli SimpleRNN katmanı 
model.add(SimpleRNN(units=20, activation='tanh'))

# 10 nöronlu Dense (Tam Bağlantılı) katman
model.add(Dense(units=10, activation='relu'))

# Görevimize özel (Maaş tahmini) çıktı katmanı: 
# Tek bir sürekli değer tahmin ettiğimiz için 1 nöronlu lineer katman
model.add(Dense(units=1, activation='linear'))

# %% [markdown]
# ❓ **Soru**: RNN'inizde kaç tane eğitilebilir parametre var ❓

# %%
# Modelin mimarisini ve parametre sayısını görmek için
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 10, 3)          │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 20)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 708 (2.77 KB)
#  Trainable params: 701 (2.74 KB)
#  Non-trainable params: 7 (32.00 B)

# %% [markdown]
# ❓ **Soru** ❓ Parametre sayısını elle yeniden hesaplamaya çalışın.

# %% [markdown]
# > Normalization Katmanı (7 Parametre): Bu katman eğitilebilir (trainable) değildir. Girdiğimiz 3 özelliğin (maaş, sorumluluk, şirket boyutu) her biri için ortalama ve varyans değerlerini tutar ($3 \times 2 = 6$). Ayrıca veri sayısını sayan 1 adet sayaç tutar. Toplam: 7.SimpleRNN Katmanı (480 Parametre): RNN'deki parametre hesaplama formülü şu şekildedir: $Nöron Sayısı \times (Girdi Özellik Sayısı + Nöron Sayısı + 1 (Bias))$.Formülü uygularsak: $20 \times (3 + 20 + 1) = 20 \times 24 = 480$ eğitilebilir parametre.İlk Dense Katmanı (210 Parametre): Standart tam bağlantılı katman formülü: $Nöron Sayısı \times (Girdi Sayısı + 1 (Bias))$. Bir önceki RNN katmanından 20 çıktı geldiği için girdi 20'dir.Formülü uygularsak: $10 \times (20 + 1) = 10 \times 21 = 210$ eğitilebilir parametre.Son Dense (Çıktı) Katmanı (11 Parametre): Bir önceki katmandan 10 çıktı geliyor ve 1 nöronumuz var.Formülü uygularsak: $1 \times (10 + 1) = 11$ eğitilebilir parametre.(Toplam Eğitilebilir: 480 + 210 + 11 = 701)

# %% [markdown]
# <details>
#     <summary><i>Cevap</i></summary>
#
#
# - <u> Normalizasyon Katmanı</u>:
#     - Bu katman normalize edilecek $\color{red}{n_x = 3} $ özelliğe (maaş, sorumluluk, şirket büyüklüğü) sahiptir. Her biri için <font color=blue>_ortalama_</font> ve <font color=blue>_standart_sapma_</font> hesaplanması gerekir. Yani $\color{red}{n_x = 3} \times \color{blue}{2} = 6$ eğitilemez parametremiz vardır. 7. parametre başlangıçta 0'a ayarlanmış bir bias'tır.
#
# - <u> Tekrarlayan Katman</u>:
#     - Eğer $\color{green}{n_h = 20} $ RNN ünitesi $\color{red}{n_x = 3} $ özelliğe paralel uygulanırsa, Tekrarlayan Katman $\color{green}{n_h}(\color{green}{n_h} + \color{red}{n_x} + 1) = \color{green}{20} \times (\color{green}{20}+\color{red}{3}+1) = \color{green}{20} \times 24 = 480$ eğitilebilir parametreye sahiptir.
#     - Bu sayının her sekansın uzunluğundan (burada 10 gün) *bağımsız* olduğuna dikkat edin
#
# - <u> Yoğun Katman</u>:
#     - $\color{green}{n_h = 20} $ RNN ünitesi ve $1$ bias ile başlayarak, 10 nöron kullanarak, Yoğun Katman $ (\color{green}{20}+1) \times 10 = 21 \times 10 = 210$ parametreye sahiptir
#
# - <u> Tahmin Yoğun Katmanı</u>:
#     - $10$ nöron ve $1$ bias ile başlayarak, 11. maaşı tahmin etmek için 1 nöron kullanarak, Tahmin Yoğun Katmanı $ (10+1) \times 1 = 11 \times 1 = 11$ parametreye sahiptir
#
# </details>

# %% [markdown]
# ❓ **Soru** ❓ Modelinizi derleyin. RNN için ***rmsprop*** optimizer'ını (*adam* yerine) kullanmanızı öneriyoruz.

# %%
# Modeli derliyoruz
model.compile(
    optimizer='rmsprop', # Yönergede istenen optimizer
    loss='mse',          # Regresyon görevleri için Mean Squared Error (Hata Kareler Ortalaması)
    metrics=['mae']      # Modelin performansını okuyabilmemiz için Mean Absolute Error (Ortalama Mutlak Hata)
)

# %% [markdown]
# ❓ **Sorular** ❓
#
# * Modelinizi eğitim veri setinizde eğitin:
#     * %20'lik bir Doğrulama Bölümü kullanın
#     * ve sabır $= 5 $ olan bir Erken Durdurma Kriteri kullanın
# * Test setindeki performansınızı değerlendirin

# %%
from keras.callbacks import EarlyStopping

# 1. Erken durdurma kriterini tanımlıyoruz
# patience=5: Doğrulama hatası 5 adım boyunca düşmezse eğitimi durdur.
# restore_best_weights=True: Eğitimi kestiğinde en iyi ağırlıklara geri dön.
es = EarlyStopping(patience=5, restore_best_weights=True)

# 2. Modeli eğitiyoruz
history = model.fit(
    X_train, y_train,
    validation_split=0.2, # Verinin %20'sini doğrulama için ayır
    epochs=100,           # Maksimum epoch sayısı (Erken durdurma keseceği için yüksek tutabiliriz)
    batch_size=32,        # Standart yığın boyutu
    callbacks=[es],       # Erken durdurmayı devreye sok
    verbose=1             # Eğitim sürecini ekranda göster
)

# 3. Test setindeki performansımızı değerlendiriyoruz
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
print(f"\nRNN Modelimizin Test MAE (Ortalama Mutlak Hata) Skoru: {test_mae:.3f}")
# Out:
# Epoch 1/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 18.5513 - mae: 1.7252 - val_loss: 3.4376 - val_mae: 0.6052
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2.9459 - mae: 0.5091 - val_loss: 1.2433 - val_mae: 0.3658
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.4888 - mae: 0.3971 - val_loss: 0.9065 - val_mae: 0.4172
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.0771 - mae: 0.3694 - val_loss: 0.7569 - val_mae: 0.3383
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9283 - mae: 0.3526 - val_loss: 0.6912 - val_mae: 0.2752
# Epoch 6/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.8564 - mae: 0.3500 - val_loss: 0.6575 - val_mae: 0.3378
# Epoch 7/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.8153 - mae: 0.3437 - val_loss: 0.6145 - val_mae: 0.2647
# Epoch 8/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.7792 - mae: 0.3367 - val_loss: 0.6220 - val_mae: 0.2918
# Epoch 9/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.7445 - mae: 0.3383 - val_loss: 0.5959 - val_mae: 0.3055
# Epoch 10/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.7420 - mae: 0.3351 - val_loss: 0.6043 - val_mae: 0.3074
# Epoch 11/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.7151 - mae: 0.3300 - val_loss: 0.5790 - val_mae: 0.2661
# Epoch 12/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.7115 - mae: 0.3325 - val_loss: 0.5689 - val_mae: 0.3062
# Epoch 13/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.7028 - mae: 0.3273 - val_loss: 0.5872 - val_mae: 0.2871
# Epoch 14/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6889 - mae: 0.3297 - val_loss: 0.5562 - val_mae: 0.2581
# Epoch 15/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6791 - mae: 0.3275 - val_loss: 0.5614 - val_mae: 0.2918
# Epoch 16/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6677 - mae: 0.3291 - val_loss: 0.7284 - val_mae: 0.4983
# Epoch 17/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.6699 - mae: 0.3318 - val_loss: 0.5264 - val_mae: 0.2444
# Epoch 18/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6735 - mae: 0.3262 - val_loss: 0.5450 - val_mae: 0.3125
# Epoch 19/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6637 - mae: 0.3268 - val_loss: 0.5225 - val_mae: 0.2472
# Epoch 20/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6532 - mae: 0.3259 - val_loss: 0.5386 - val_mae: 0.2651
# Epoch 21/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6553 - mae: 0.3280 - val_loss: 0.5347 - val_mae: 0.2619
# Epoch 22/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6524 - mae: 0.3250 - val_loss: 0.5142 - val_mae: 0.2397
# Epoch 23/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6454 - mae: 0.3263 - val_loss: 0.5692 - val_mae: 0.3059
# Epoch 24/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6478 - mae: 0.3228 - val_loss: 0.5381 - val_mae: 0.2479
# Epoch 25/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6485 - mae: 0.3252 - val_loss: 0.5182 - val_mae: 0.2714
# Epoch 26/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6391 - mae: 0.3219 - val_loss: 0.5183 - val_mae: 0.2660
# Epoch 27/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6366 - mae: 0.3243 - val_loss: 0.5175 - val_mae: 0.2493
#
# RNN Modelimizin Test MAE (Ortalama Mutlak Hata) Skoru: 0.258

# %% [markdown]
# ## (3) 💻 Temel karşılaştırma

# %% [markdown]
# > ❗️ **Önemli hatırlatma** ❗️
# >
# > ***Derin Öğrenme modellerinizi ve daha genel olarak herhangi bir Makine Öğrenmesi modelini her zaman bir temel modelle karşılaştırmayı unutmayın.***
#
# 🧑🏻‍🏫 Amacımızın çalışanların 11. yıl için maaşını tahmin etmek olduğunu unutmayın. Bu bir ***Regresyon görevidir***. Hangi temel modeli oluşturabiliriz?
# 1. Geleneksel regresyon modeli durumunda, `y_test` için temel tahmin **`y_train`'in ortalamasını tahmin etmektir**... ancak bu seçenek zamanla ilgili seriler için alakasız olabilir. Teorik olarak, birinin maaşının yıllar içinde artması gerekir!
# 2. Regresyon görevi için alternatif temel tahmin **son görülen değeri tahmin etmektir**

# %% [markdown]
# ❓ **Sorular** ❓
# * 10. ve 11. yıl arasında maaşın sabit kaldığını tahmin eden temel modelin Ortalama Mutlak Hatasını hesaplayın
# * Bu temel modeli RNN'inizle karşılaştırın

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error

# 1. Temel model tahmini: 10. yılın maaşı (son zaman adımı, 0. özellik)
y_pred_baseline = X_test[:, -1, 0]

# 2. Temel modelin MAE'sini hesaplayalım
baseline_mae = mean_absolute_error(y_test, y_pred_baseline)

# 3. Sonuçları karşılaştıralım
print(f"Temel Model (Son Maaşı Tekrar Etme) MAE Skoru: {baseline_mae:.3f}")
print(f"Bizim RNN Modelimizin MAE Skoru:               {test_mae:.3f}")

print("\nSonuç:")
if test_mae < baseline_mae:
    print("Tebrikler! RNN modelin basit bir tahminden daha iyi bir örüntü yakalamış! 🎉")
else:
    print("RNN modelimiz henüz basit tahminin gerisinde. Belki biraz hiperparametre ayarı gerekir. 🤔")
# Out:
# Temel Model (Son Maaşı Tekrar Etme) MAE Skoru: 0.607
# Bizim RNN Modelimizin MAE Skoru:               0.258
#
# Sonuç:
# Tebrikler! RNN modelin basit bir tahminden daha iyi bir örüntü yakalamış! 🎉

# %% [markdown]
# 👉 Bu soruda takılırsanız, `(4) LSTM`'i deneyin ve sonra buraya geri dönün.
#
# 🧑🏻‍🏫 Gerekirse TA'ya sorun. Cevaba sadece bu soruları başarısızlıkla cevaplamaya çalıştıktan sonra bakın.
#
# <details>
#     <summary><i>Cevap</i></summary>
#
#
# ```python
# # Bir sonraki maaşı tahmin etmek için X'teki son maaşı kullanma
# y_test_baseline = X_test[:, -1, 0]
# mae_baseline = np.mean(np.abs(y_test - y_test_baseline))
# ```
#
# </details>

# %% [markdown]
# 😁 RNN'inizin temel modelden biraz daha iyi performans gösterdiğini fark etmelisiniz.

# %% [markdown]
# ## (4) 💻 LSTM: Uzun-Kısa Süreli Bellek

# %% [markdown]
# ❓ **Sorular** ❓
#
# * Aynı modeli yazın, ancak `SimpleRNN` katmanı yerine `LSTM` katmanı ile
# * Test setindeki performansınızı değerlendirin

# %%
from keras.layers import LSTM

# 1. Aynı modeli SimpleRNN yerine LSTM kullanarak inşa ediyoruz
lstm_model = Sequential()
lstm_model.add(Input(shape=(10, 3)))
lstm_model.add(normalizer) # Daha önce eğittiğimiz normalizer'ı aynen kullanabiliriz
lstm_model.add(LSTM(units=20, activation='tanh')) # İşte sihrin gerçekleştiği yer!
lstm_model.add(Dense(units=10, activation='relu'))
lstm_model.add(Dense(units=1, activation='linear'))

# 2. Modeli derliyoruz
lstm_model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# 3. Modeli eğitiyoruz
print("LSTM Modeli Eğitiliyor...\n")
lstm_history = lstm_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[es], # Aynı erken durdurma kuralını (EarlyStopping) kullanıyoruz
    verbose=1
)

# 4. Performansı değerlendiriyoruz
lstm_test_loss, lstm_test_mae = lstm_model.evaluate(X_test, y_test, verbose=0)

print("\n--- SONUÇLAR ---")
print(f"Temel Model MAE: {baseline_mae:.3f}")
print(f"SimpleRNN MAE:   {test_mae:.3f}")
print(f"LSTM MAE:        {lstm_test_mae:.3f}")
# Out:
# LSTM Modeli Eğitiliyor...
#
# Epoch 1/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 18.9967 - mae: 1.9562 - val_loss: 3.5480 - val_mae: 0.7923
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.8596 - mae: 0.5903 - val_loss: 1.1925 - val_mae: 0.4288
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.2523 - mae: 0.3700 - val_loss: 0.7481 - val_mae: 0.2866
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9429 - mae: 0.3276 - val_loss: 0.6437 - val_mae: 0.2609
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.8152 - mae: 0.3107 - val_loss: 0.6180 - val_mae: 0.2746
#
# --- SONUÇLAR ---
# Temel Model MAE: 0.607
# SimpleRNN MAE:   0.258
# LSTM MAE:        0.852

# %% [markdown]
# 💪 LSTM, daha düşük MAE ile SimpleRNN'den biraz daha iyi performans göstermelidir.

# %% [markdown]
# 🏁 Tebrikler! Sıralı veriler üzerinde RNN eğitmeyi öğrendiniz.
#
#
# 💾 Notebook'unuzu git add/commit/push yapmayı unutmayın...
#
# 🚀 ... ve sonraki challenge'a geçin!
#
# ---
#
# <u>Not</u>: Üzerinde çalıştığınız sekanslar tamamen sahte. Benzer verileri eğitmeniz ve üretmeniz gerektiğinde, böyle bir veri setini simüle etmek için kullanılan fonksiyonları aşağıda bulabilirsiniz.

# %% [markdown]
# ## 🛠 (Yardımcı Araçlar)

# %%
def create_sequences(number):
    X, y = [], []

    for i in range(number):
        x_i, y_i = create_individual_sequence(10)
        X.append(x_i)
        y.append(y_i)

    return np.array(X), np.array(y)

def create_individual_sequence(length):
    company_sizes = []
    nb_persons = []
    salaries = []


    # Education level
    educ_level = [max(0, int(np.random.normal(10, 2)))]*length

    # Company size
    current_size = int(1 + np.random.beta(.4, 4)*500)
    for i in range(length):
        if not np.random.randint(4): # Change 1 out of 3 possibilities
            current_size = int(max(1, np.random.normal(current_size, 50)))
        company_sizes.append(current_size)

    # Number of persons
    nb_iter = np.random.beta(.15, 4)*300
    for i in range(length):
        if not np.random.randint(2): # Change 1 out of 2 possibilities
            R_1 = np.random.beta(0.5, 8)*3
            nb_iter = nb_iter + max(-2, R_1*company_sizes[i] + np.random.randint(-2, 2))
            nb_iter = max(0, nb_iter)
            nb_iter = int(min(company_sizes[i]-1, nb_iter))
        nb_persons.append(nb_iter)


    # Salary
    salary_iter = max(800, int(np.random.normal(1200, 300)+ 0.05*company_sizes[0] +  np.random.normal(40, 400)))
    salaries.append(salary_iter)
    for i in range(1, length + 1):
        R_1 = np.random.normal(100, 50)
        change_person = nb_persons[i-1] - nb_persons[i-2]
        change_company = max(0, company_sizes[i-1] - company_sizes[i-2])
        salary_iter = salary_iter + 0.05*change_company + change_person*R_1 + np.random.normal(100, 50)
        salary_iter = max(int(salary_iter), 500)

        salaries.append(salary_iter)

    y = salaries[-1]/1000
    salaries = [_/1000 for _ in salaries[:-1]]

    return np.array([salaries, nb_persons, company_sizes]).T, y

# %%
#X, y = create_sequences(25000)

#np.save('X', X.astype(np.float32))
#np.save('y', y)
